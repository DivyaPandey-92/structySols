# %%
class Node:
  def __init__(self, val):
    self.val = val
    self.next = None

def add_lists(head_1, head_2):
  # head=Node(None)
  return _add_lists(head_1, head_2, 0)
  
   
def _add_lists(head_1, head_2, carry):
  pass # tod


  if head_1 is None and head_2 is None and carry ==0:
    return None
  
  val_1=0 if head_1 is None else head_1.val
  val_2=0 if head_2 is None else head_2.val
  
  sum=val_1+val_2+carry
  carry=1 if sum>9 else 0
  
  digit=sum%10
  head=Node(digit)
  
  next1=None if head_1 is None else head_1.next
  next2=None if head_2 is None else head_2.next
  
  head.next = _add_lists(next1, next2,  carry)
  
  return head
  
  
  
  
  
  
  
  
  
  
  
  
  
#   if head_1 is None:
#     head_1.val=0
#     if carry==1:
#       digit= head_1.val + head_2.val+1
#     else:
#       digit=head_1.val+head2.va1+head_1
    
#     head=Node(digit)
#     head.next=_add_lists(head_1, head_2.next, head)  
    
#   elif head_2 is None:
#     head_2.val=0
#     digit= head_1.val + head_2.val
#     head=Node(digit)
#     head.next=_add_lists(head_1.next, head_2, head)  
    
#   else:
    
#     digit= head_1.val + head_2.val
#     head=Node(digit)

#     head.next=_add_lists(head_1.next, head_2.next, head) 
    
#   return head
